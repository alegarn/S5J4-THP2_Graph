# %% [markdown]
# # Des graphes, des graphes, des graphes, des graphes
#
# ## 1. Introduction
#
# Aujourd'hui on va se mettre en mode Kata. A l'origine, un Kata désigne la répétition d’une séquence de gestes techniques dans de nombreux arts martiaux japonais 🥋🥋 Rassurez-vous, notre but ici n'est pas de vous transformer en maître accompli des arts martiaux, mais plutôt de vous partager une méthode d’apprentissage qui permet aux programmeurs et aux programmeuses de perfectionner leurs compétences, à travers la pratique et la répétition !
#
# ## 2. Le projet
#
# ### 2.1. Graphe 1
#
# Réaliser un graphique avec deux axes. L'axe des abscisses va de 0 à 50 et s'intitule "Axe des x". L'axe des ordonnées s'intitule "Axe des y".
# Tracer la droite d'équation : x = 3y. Avec x allant de 0 à 50.
# Le graphe possède le titre suivant "Tracer une droite" et la droite est de couleur rouge.
#
# ### 2.2. Graphe 2
#
# Pour les graphes suivants, tu peux télécharger le fichier des ventes 2020 d'une entreprise de cosmétiques ici.
#
# En premier lieu, nous souhaitons un graphe qui donne la courbe du profit total réalisé chaque mois.
#
# ### 2.3. Graphe 3
#
# Ensuite, nous souhaitons un graphe qui donne la courbe de profit pour chaque produit, en fonction du temps.
# Chaque courbe aura une couleur différente et nous souhaitons une légende qui indique quelle couleur correspond à quel produit.
#
# ### 2.4. Graphe 4
#
# Nous souhaitons un graphe qui compare, chaque mois, le nombre d'unités vendus pour chaque produit. A vous de choisir la meilleure représentation pour connaître le produit le plus vendu par mois.
#
# ### 2.5. Graphe 5
#
# Nous souhaitons un graphe qui donne la contribution de chaque produit dans le profit total (sur l'année étudiée). Merci d'ajouter le pourcentage pour chaque produit.
#
# ### 2.6. Graphe 6
#
# Maintenant, on va changer de source de données. Et on va revenir au projet d'hier. Demande-toi si hier, tu as pensé à faire des graphes. Si oui, c'est top, ça montre que c'est intuitif de devoir visualiser certaines données. Si non, c'est normal, on n'avait pas encore vu ça dans les ressources. Sache qu'à partir de maintenant, tout va te paraître plus facile car tu penseras toujours faire des représentations graphiques.
#
# Reprend donc les 3 fichiers csv qui donnent les ventes, la liste des clients et la liste des produits.
#
# D'abord, nous souhaitons avoir un graphe pie chart qui donne la répartition des produits par catégorie. Merci d'indiquer le pourcentage par produit (nb de produits de telle catégorie / nb de produits totaux).
#
# ### 2.7. Graphe 7
#
# Nous souhaitons un graphe qui donne l'évolution du CA pour chaque catégorie (en fonction du temps).
#
# ### 2.8. Graphe 8
#
# Nous souhaitons un graphe qui donne un boxplot de la répartion des prix d'un produit pour chaque catégorie. En clair, le graphe montre 3 boxplots (un qui correspond à la catégorie 0, un à la catégorie 1 et un à la catégorie 2).
#
# ### 2.9. Graphe 9
#
# Nous souhaitons un graphe qui donne la répartition du CA, pour chaque mois, en fonction du genre du client.
#
# ### 2.10. Graphe 10
#
# Nous souhaitons un graphe qui, pour chaque transaction, lie tranche d'âge du client et montant de la transaction.
# 2.11. Graphe 11
#
# Nous souhaitons un graphe qui, pour chaque article, lie prix et nombre d'articles vendus pendant la période.
# 2.12. Graphe 12
#
# Nous souhaitons un graphe qui donne la répartition du panier moyen (à chaque transaction).
# 2.13 Autres graphes
#
# Trouver 3 autres graphes qui peuvent être utiles à la compréhension des ventes de la chaîne de librairies.

# %% [markdown]
# ### 2.1. Graphe 1
#
# Réaliser un graphique avec deux axes. L'axe des abscisses va de 0 à 50 et s'intitule "Axe des x". L'axe des ordonnées s'intitule "Axe des y".
# Tracer la droite d'équation : x = 3y. Avec x allant de 0 à 50.
# Le graphe possède le titre suivant "Tracer une droite" et la droite est de couleur rouge.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# https://matplotlib.org/2.0.2/api/pyplot_api.html
# https://moonbooks.org/Articles/Tracer-une-ligne-droite-avec-matplotlib/
#plt.plot([0.0, 10.0], [0.0, 10.0] ) # Red straight line


def f(x):
    return x/3

plt.title("x = 3y ")
plt.xlabel("Axe des x")
plt.ylabel("Axe des y")
plt.plot([f(x) for x in range(0,50)],'r-', lw=2)
plt.show()

# %% [markdown]
# ### 2.2. Graphe 2
#
# Pour les graphes suivants, tu peux télécharger le fichier des ventes 2020 d'une entreprise de cosmétiques ici.
#
# En premier lieu, nous souhaitons un graphe qui donne la courbe du profit total réalisé chaque mois.

# %%
df_comp_sales = pd.read_csv(r'company_sales_data.csv', sep=',') 


#https://moonbooks.org/Articles/How-to-convert-a-dataframe-column-to-an-array-with-pandas-/#convert-a-column-of-strings
month = df_comp_sales['month_number'].to_numpy()
value = df_comp_sales['total_profit'].to_numpy()
# https://pythonspot.com/matplotlib-bar-chart/
plt.bar(month, value, align='center', alpha=0.5)

#plt.plot()
plt.show()

# %% [markdown]
# ### 2.3. Graphe 3
#
# Ensuite, nous souhaitons un graphe qui donne la courbe de profit pour chaque produit, en fonction du temps.
# Chaque courbe aura une couleur différente et nous souhaitons une légende qui indique quelle couleur correspond à quel produit.

# %%
df_comp_sales 

# https://www.geeksforgeeks.org/plot-multiple-lines-in-matplotlib/
month = df_comp_sales['month_number'].to_numpy()
facecream = df_comp_sales['facecream'].to_numpy()
facewash = df_comp_sales['facewash'].to_numpy()
toothpaste = df_comp_sales['toothpaste'].to_numpy()
bathingsoap = df_comp_sales['bathingsoap'].to_numpy()
shampoo = df_comp_sales['shampoo'].to_numpy()
moisturizer = df_comp_sales['moisturizer'].to_numpy()

plt.plot(month, facecream*10, label = "facecream")
plt.plot(month, facewash*10, label = "facewash")
plt.plot(month, toothpaste*10, label = "toothpaste")
plt.plot(month, bathingsoap*10, label = "bathingsoap")
plt.plot(month, shampoo*10, label = "shampoo")
plt.plot(month, moisturizer*10, label = "moisturizer")

# https://www.geeksforgeeks.org/change-plot-size-in-matplotlib-python/
plt.rcParams['figure.figsize'] = [12, 10]
plt.xlabel('Numéro du mois')
plt.ylabel('Compte des profits par produit')
plt.legend()
plt.show()

# %% [markdown]
# ### 2.4. Graphe 4
#
# Nous souhaitons un graphe qui compare, chaque mois, le nombre d'unités vendus pour chaque produit. A vous de choisir la meilleure représentation pour connaître le produit le plus vendu par mois.

# %%
plt.plot(month, facecream, label = "facecream")
plt.plot(month, facewash, label = "facewash")
plt.plot(month, toothpaste, label = "toothpaste")
plt.plot(month, bathingsoap, label = "bathingsoap")
plt.plot(month, shampoo, label = "shampoo")
plt.plot(month, moisturizer, label = "moisturizer")
# https://www.geeksforgeeks.org/change-plot-size-in-matplotlib-python/
plt.rcParams['figure.figsize'] = [12, 10]
plt.xlabel('Numéro du mois')
plt.ylabel("Nombre d'unité par produit")
plt.legend()
plt.show()

# %% [markdown]
# # 2.5. Graphe 5
#
# Nous souhaitons un graphe qui donne la contribution de chaque produit dans le profit total (sur l'année étudiée). Merci d'ajouter le pourcentage pour chaque produit.

# %%
# transformer en % (avec des profits totaux)

total_profit = df_comp_sales['total_profit'].to_numpy()
total_units = df_comp_sales['total_units'].to_numpy()
plt.plot(month, facecream*100/total_units, label = "facecream")
plt.plot(month, facewash*100/total_units, label = "facewash")
plt.plot(month, toothpaste*100/total_units, label = "toothpaste")
plt.plot(month, bathingsoap*100/total_units, label = "bathingsoap")
plt.plot(month, shampoo*100/total_units, label = "shampoo")
plt.plot(month, moisturizer*100/total_units, label = "moisturizer")

# https://www.geeksforgeeks.org/change-plot-size-in-matplotlib-python/
plt.rcParams['figure.figsize'] = [12, 10]
plt.xlabel('Numéro du mois')
plt.ylabel("Contribution d'un produit aux profits (%)")
plt.legend()
plt.show()

# %%
df_comp_sales
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %% [markdown]
# # 2.6. Graphe 6
#
# Maintenant, on va changer de source de données. Et on va revenir au projet d'hier. Demande-toi si hier, tu as pensé à faire des graphes. Si oui, c'est top, ça montre que c'est intuitif de devoir visualiser certaines données. Si non, c'est normal, on n'avait pas encore vu ça dans les ressources. Sache qu'à partir de maintenant, tout va te paraître plus facile car tu penseras toujours faire des représentations graphiques.
#
# Reprend donc les 3 fichiers csv qui donnent les ventes, la liste des clients et la liste des produits.
#
# D'abord, nous souhaitons avoir un graphe pie chart qui donne la répartition des produits par catégorie. Merci d'indiquer le pourcentage par produit (nb de produits de telle catégorie / nb de produits totaux).

# %%
df_c = pd.read_csv(r'dataset_bookstore/customers.csv')
df_p = pd.read_csv(r'dataset_bookstore/products.csv')
df_t = pd.read_csv(r'dataset_bookstore/transactions.csv')

cust_trans = pd.merge(df_t, df_c, on="client_id")
file = pd.merge(cust_trans, df_p, on="id_prod")

file.dropna()

file = file.loc[file["price"] > 0].sort_values('price', ascending = False)

# %%
df_p.count()
all_cat = ['0', '1', '2']
df_prod_grp = df_p.groupby('id_prod')
df_cat_grp = df_p[['id_prod','categ']].groupby('categ').size()

# https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html
# https://stackoverflow.com/questions/46542572/how-to-plot-pie-chart-using-data-frame-group-by-different-range
df_cat_grp.plot.pie(autopct='%1.1f%%',shadow=True, startangle=90, figsize = [8,8])
plt.title('répartition des produits par catégorie')
plt.legend()
plt.ylabel('categ')
plt.show()

# %% [markdown]
# # 2.7. Graphe 7
#
# Nous souhaitons un graphe qui donne l'évolution du CA pour chaque catégorie (en fonction du temps).

# %%
file['day'] = file['date'].str[:11]
file['month'] = file['date'].str[:7]
per_day = file.groupby('day', as_index=False)
per_month = file.groupby('month', as_index=False)
file['price'].astype(float)

monthly_turnover = per_month['price'].sum().add_suffix('_sum')
daily_turnover = per_day['price'].sum().add_suffix('_sum')

file_cat_0 = file.loc[file["categ"] == 0].sort_values('price', ascending = False)
file_cat_1 = file.loc[file["categ"] == 1].sort_values('price', ascending = False)
file_cat_2 = file.loc[file["categ"] == 2].sort_values('price', ascending = False)

per_month_0 = file_cat_0.groupby('month', as_index=False)
per_month_1 = file_cat_1.groupby('month', as_index=False)
per_month_2 = file_cat_2.groupby('month', as_index=False)

monthly_turnover_cat_0 = per_month_0['price'].sum().add_suffix('_sum_cat_0')
monthly_turnover_cat_1 = per_month_1['price'].sum().add_suffix('_sum_cat_1')
monthly_turnover_cat_2 = per_month_2['price'].sum().add_suffix('_sum_cat_2')

monthly_turnover['price_sum_cat_0'] = monthly_turnover_cat_0['price_sum_cat_0']
monthly_turnover['price_sum_cat_1'] = monthly_turnover_cat_1['price_sum_cat_1']
monthly_turnover['price_sum_cat_2'] = monthly_turnover_cat_2['price_sum_cat_2']

monthly_turnover.set_index('month_sum')
month = monthly_turnover['month_sum'].to_numpy()

# %%
price_sum_cat_0 = monthly_turnover['price_sum_cat_0'].to_numpy()
price_sum_cat_1 = monthly_turnover['price_sum_cat_1'].to_numpy()
price_sum_cat_2 = monthly_turnover['price_sum_cat_2'].to_numpy()

plt.plot(month, price_sum_cat_0, label = "profit_cat_0")
plt.plot(month, price_sum_cat_1, label = "profit_cat_1")
plt.plot(month, price_sum_cat_2, label = "profit_cat_2")

x = np.arange(len(month))  # the label locations
width = 0.3  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width*0.8, price_sum_cat_0, width, label='profit_cat_0')
rects2 = ax.bar(x + width/5, price_sum_cat_1, width, label='profit_cat_1')
rects3 = ax.bar(x + width*1.2, price_sum_cat_2, width, label='profit_cat_2')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Cat_profits')
ax.set_title('évolution du CA pour chaque catégorie')
ax.set_xticks(x, month.any())
ax.legend()


fig.tight_layout()

#plt.bar(monthly_turnover['month_sum'], monthly_turnover['price_sum_cat_0'], align='center', alpha=0.5)

# %% [markdown]
# ### 2.8. Graphe 8
#
# Nous souhaitons un graphe qui donne un boxplot de la répartion des prix d'un produit pour chaque catégorie. En clair, le graphe montre 3 boxplots (un qui correspond à la catégorie 0, un à la catégorie 1 et un à la catégorie 2).

# %%
file_cat = file.pivot_table(index=['id_prod'], values=['price'], columns=['categ'], aggfunc='size')

file_cat
#file_cat = file.groupby('categ')
#file_cat
#boxplot = file_cat_0.boxplot(column = ['price'], by=['categ'])
#boxplot
# Out:
# categ        0   1      2
# id_prod
# 0_0      611.0 NaN    NaN
# 0_1      249.0 NaN    NaN
# 0_10      12.0 NaN    NaN
# 0_100      2.0 NaN    NaN
# 0_1000   222.0 NaN    NaN
# ...        ...  ..    ...
# 2_95       NaN NaN    3.0
# 2_96       NaN NaN  281.0
# 2_97       NaN NaN    5.0
# 2_98       NaN NaN    1.0
# 2_99       NaN NaN    2.0
#
# [3264 rows x 3 columns]

# %% [markdown]
# ### 2.9. Graphe 9
#
# Nous souhaitons un graphe qui donne la répartition du CA, pour chaque mois, en fonction du genre du client.

# %%
#file_cat = file.pivot_table(index=['sex'], values=['price'], columns=['id_prod'], aggfunc='sum')
#file_cat
fem = file.loc[file["sex"] == "f"].sort_values('price', ascending = False)
mas = file.loc[file["sex"] == "m"].sort_values('price', ascending = False)

by_fem = fem.groupby('month', as_index=False)
cum_fem = by_fem['price'].sum().add_suffix('_sum_fem')
cum_fem = cum_fem.set_index('month_sum_fem')

by_mas = mas.groupby('month', as_index=False)
cum_mas = by_mas['price'].sum().add_suffix('_sum_mas')
cum_mas = cum_mas.set_index('month_sum_mas')


#cum_gend = cum_fem
#cum_gend['price_sum_mas'] = cum_mas['price_sum_mas']
#cum_gend = cum_gend.set_index('month_sum_fem')

# %%
labels = cum_fem.index.tolist()
x = np.arange(len(labels))  # the label locations
width = 0.3  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, cum_mas['price_sum_mas'], width, label='profit_mas')
rects2 = ax.bar(x + width/2, cum_fem['price_sum_fem'], width, label='profit_fem')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('gend_profits')
ax.set_title('évolution du CA pour chaque sexe')
ax.set_xticks(x, labels)
ax.legend()

#ax.bar_label(rects1, padding=3)
#ax.bar_label(rects2, padding=3)

fig.tight_layout()

# %% [markdown]
# # 2.10. Graphe 10
#
# Nous souhaitons un graphe qui, pour chaque transaction, lie tranche d'âge du client et montant de la transaction.
